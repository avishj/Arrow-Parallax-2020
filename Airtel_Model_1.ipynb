# %%
from datetime import datetime as dt,timedelta as td
import pandas_datareader.data as web
import pandas as pd
import numpy as np

# %%
start_date=dt(2010,1,1)
end=dt.strftime(dt.today()-td(1),'%Y-%m-%d')
df_sbi=web.DataReader('BHARTIARTL.NS','yahoo',start_date,end)
df_sbi.tail()
# Out:
#                   High         Low  ...      Volume   Adj Close
# Date                                ...
# 2020-02-14  567.549988  534.250000  ...  36826473.0  565.000000
# 2020-02-17  568.700012  556.500000  ...  22924036.0  564.849976
# 2020-02-18  568.849976  537.299988  ...  21462600.0  548.250000
# 2020-02-19  553.599976  538.750000  ...  21681078.0  543.400024
# 2020-02-20  552.000000  538.599976  ...  15715009.0  545.599976
#
# [5 rows x 6 columns]

# %%
X=df_sbi.filter(['Close'])
X=X.values
X
# Out:
# array([[298.5920105 ],
#        [303.32000732],
#        [300.10699463],
#        ...,
#        [548.25      ],
#        [543.40002441],
#        [545.59997559]])

# %%
from sklearn.preprocessing import MinMaxScaler as mms
scaler=mms(feature_range=(0,1))
X=scaler.fit_transform(X)

# %%
import math as m
x_train_len=m.ceil(X.shape[0]*0.8)
x_train_len
# Out:
# 1999

# %%
x_train=list()
y_train=list()
for i in range(1,x_train_len):
  x_train.append(X[i-1:i])
  y_train.append(X[i,])
x_train=np.array(x_train)
y_train=np.array(y_train)
x_train=np.reshape(x_train,(x_train.shape[0],x_train.shape[1],1))
x_train.shape
# Out:
# (1998, 1, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Dense

model=Sequential()
model.add(LSTM(70,return_sequences=True,input_shape=(x_train.shape[1],1)))
model.add(LSTM(70,return_sequences=False))
model.add(Dense(70))
model.add(Dense(1))

model.compile(loss='mean_squared_error',optimizer='adam')
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 1, 70)             20160
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 70)                39480
# _________________________________________________________________
# dense_2 (Dense)              (None, 70)                4970
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 71
# =================================================================
# Total params: 64,681
# Trainable params: 64,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train,y_train,batch_size=32,epochs=50)
# Out:
# Train on 1998 samples
# Epoch 1/50
# 1998/1998 [==============================] - 2s 1ms/sample - loss: 0.0219
# Epoch 2/50
# 1998/1998 [==============================] - 0s 208us/sample - loss: 0.0017
# Epoch 3/50
# 1998/1998 [==============================] - 0s 222us/sample - loss: 3.6192e-04
# Epoch 4/50
# 1998/1998 [==============================] - 0s 222us/sample - loss: 3.5940e-04
# Epoch 5/50
# 1998/1998 [==============================] - 0s 213us/sample - loss: 3.5152e-04
# Epoch 6/50
# 1998/1998 [==============================] - 0s 203us/sample - loss: 3.4527e-04
# Epoch 7/50
# 1998/1998 [==============================] - 0s 200us/sample - loss: 3.4820e-04
# Epoch 8/50
# 1998/1998 [==============================] - 0s 200us/sample - loss: 3.4596e-04
# Epoch 9/50
# 1998/1998 [==============================] - 0s 199us/sample - loss: 3.7923e-04
# Epoch 10/50
# 1998/1998 [==============================] - 0s 208us/sample - loss: 3.4113e-04
# Epoch 11/50
# 1998/1998 [==============================] - 0s 222us/sample - loss: 3.4650e-04
# Epoch 12/50
# 1998/1998 [==============================] - 0s 196us/sample - loss: 3.4089e-04
# Epoch 13/50
# 1998/1998 [==============================] - 0s 204us/sample - loss: 3.5555e-04
# Epoch 45/50
# 1998/1998 [==============================] - 0s 209us/sample - loss: 3.5702e-04
# Epoch 46/50
# 1998/1998 [==============================] - 0s 208us/sample - loss: 3.8889e-04
# Epoch 47/50
# 1998/1998 [==============================] - 0s 211us/sample - loss: 3.6452e-04
# Epoch 48/50
# 1998/1998 [==============================] - 0s 211us/sample - loss: 3.4886e-04
# Epoch 49/50
# 1998/1998 [==============================] - 0s 196us/sample - loss: 3.4767e-04
# Epoch 50/50
# 1998/1998 [==============================] - 0s 205us/sample - loss: 3.6746e-04

# %%
x_test_len=m.ceil(X.shape[0]*0.2)
X_Test=X[x_test_len:]
x_test=list()
y_test=list()
X_Test=X[x_test_len:]
x_test=list()
y_test=list()
for i in range(1,x_test_len):
  x_test.append(X_Test[i-1:i])
  y_test.append(X_Test[i,])
x_test=np.array(x_test)
y_test=np.array(y_test)
x_test=np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))
x_test.shape
# Out:
# (499, 1, 1)

# %%
(1-model.evaluate(x_test,y_test))*100
# Out:
# 499/499 [==============================] - 0s 961us/sample - loss: 3.5807e-04
# 99.96419301437808

# %%
today=dt.strftime(dt.today(),'%Y-%m-%d')
df_sbi=web.DataReader('BHARTIARTL.NS','yahoo',start='2019-1-1',end=today)
df_sbi=df_sbi.filter(['Close']).values
df_sbi=scaler.fit_transform(df_sbi)
df_sbi_30=df_sbi[-60:,:]
df_sbi_30.shape
# Out:
# (60, 1)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
model.save('/content/gdrive/My Drive/Colab Notebooks/tesla_model.h5')

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler as mms
from tensorflow.keras.models import load_model
model = load_model('/content/gdrive/My Drive/Colab Notebooks/sbi_model_jo_checkkkk.h5')
def sbi_result():
  today=dt.strftime(dt.today(),'%Y-%m-%d')
  df_sbi=web.DataReader('BHARTIARTL.NS','yahoo',start='2019-1-1',end=today)
  df_sbi=df_sbi.filter(['Close']).values
  scaler=mms(feature_range=(0,1))
  df_sbi=scaler.fit_transform(df_sbi)
  df_sbi_30=df_sbi[-1:,:]
  y_30=list()
  for i in range(30):
    x_30=list()
    df_sbi_30=np.reshape(df_sbi_30,(df_sbi_30.shape[0],1))
  
    x_30=df_sbi_30[-1:,:]
    x_30=np.array(x_30)
    x_30=np.reshape(x_30,(x_30.shape[1],1,1))
    x=model.predict(x_30)
    y_30.append(x)
    df_sbi_30=np.append(df_sbi_30,x)
  y_30=np.array(y_30)
  y_30=np.reshape(y_30,(y_30.shape[0],y_30.shape[1]))
  y_30=scaler.inverse_transform(y_30)
  result=np.reshape(y_30,(30))
  return result

# %%
list(sbi_result())
# Out:
# [539.8697,
#  534.53406,
#  529.5531,
#  524.89197,
#  520.52057,
#  516.4124,
#  512.5446,
#  508.89658,
#  505.45023,
#  502.18948,
#  499.09995,
#  496.16882,
#  493.38443,
#  490.7364,
#  488.21527,
#  485.81238,
#  483.52008,
#  481.3311,
#  479.23904,
#  477.23798,
#  475.32233,
#  473.48715,
#  471.72787,
#  470.04013,
#  468.41998,
#  466.86377,
#  465.36807,
#  463.92975,
#  462.54587,
#  461.2137]
