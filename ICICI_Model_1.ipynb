# %%
from datetime import datetime as dt,timedelta as td
import pandas_datareader.data as web
import pandas as pd
import numpy as np

# %%
start_date=dt(2010,1,1)
end=dt.strftime(dt.today()-td(1),'%Y-%m-%d')
df_sbi=web.DataReader('ICICIBANK.NS','yahoo',start_date,end)
df_sbi.tail()
# Out:
#                   High         Low    Open       Close      Volume   Adj Close
# Date
# 2020-02-14  548.650024  536.549988  541.25  545.799988  14458649.0  545.799988
# 2020-02-17  545.349976  537.750000  543.00  541.599976   7793293.0  541.599976
# 2020-02-18  544.400024  536.000000  541.00  541.200012  15918303.0  541.200012
# 2020-02-19  546.500000  540.500000  543.50  544.799988   8704234.0  544.799988
# 2020-02-20  549.349976  541.799988  545.50  547.000000  13588526.0  547.000000

# %%
X=df_sbi.filter(['Close'])
X=X.values
X
# Out:
# array([[159.94500732],
#        [161.46400452],
#        [162.69999695],
#        ...,
#        [541.20001221],
#        [544.79998779],
#        [547.        ]])

# %%
from sklearn.preprocessing import MinMaxScaler as mms
scaler=mms(feature_range=(0,1))
X=scaler.fit_transform(X)

# %%
import math as m
x_train_len=m.ceil(X.shape[0]*0.8)
x_train_len
# Out:
# 1999

# %%
x_train=list()
y_train=list()
for i in range(1,x_train_len):
  x_train.append(X[i-1:i])
  y_train.append(X[i,])
x_train=np.array(x_train)
y_train=np.array(y_train)
x_train=np.reshape(x_train,(x_train.shape[0],x_train.shape[1],1))
x_train.shape
# Out:
# (1998, 1, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Dense

model=Sequential()
model.add(LSTM(70,return_sequences=True,input_shape=(x_train.shape[1],1)))
model.add(LSTM(70,return_sequences=False))
model.add(Dense(70))
model.add(Dense(1))

model.compile(loss='mean_squared_error',optimizer='adam')
model.summary()
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 1, 70)             20160
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 70)                39480
# _________________________________________________________________
# dense (Dense)                (None, 70)                4970
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 71
# =================================================================
# Total params: 64,681
# Trainable params: 64,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train,y_train,batch_size=32,epochs=50)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 1998 samples
# Epoch 1/50
# 1998/1998 [==============================] - 2s 971us/sample - loss: 0.0151
# Epoch 2/50
# 1998/1998 [==============================] - 0s 170us/sample - loss: 5.2350e-04
# Epoch 3/50
# 1998/1998 [==============================] - 0s 184us/sample - loss: 1.1995e-04
# Epoch 4/50
# 1998/1998 [==============================] - 0s 184us/sample - loss: 1.1348e-04
# Epoch 5/50
# 1998/1998 [==============================] - 0s 197us/sample - loss: 1.1338e-04
# Epoch 6/50
# 1998/1998 [==============================] - 0s 186us/sample - loss: 1.1222e-04
# Epoch 7/50
# 1998/1998 [==============================] - 0s 199us/sample - loss: 1.1710e-04
# Epoch 8/50
# 1998/1998 [==============================] - 0s 199us/sample - loss: 1.1007e-04
# Epoch 9/50
# 1998/1998 [==============================] - 0s 196us/sample - loss: 1.2756e-04
# Epoch 10/50
# 1998/1998 [==============================] - 0s 196us/sample - loss: 1.1912e-04
# Epoch 11/50
# 1998/1998 [==============================] - 0s 206us/sample - loss: 1.1666e-04
# Epoch 12/50
# 1998/1998 [==============================] - 0s 198us/sample - loss: 1.1060e-04
# Epoch 13/50
# Epoch 46/50
# 1998/1998 [==============================] - 0s 210us/sample - loss: 1.0899e-04
# Epoch 47/50
# 1998/1998 [==============================] - 0s 204us/sample - loss: 1.1539e-04
# Epoch 48/50
# 1998/1998 [==============================] - 0s 193us/sample - loss: 1.1894e-04
# Epoch 49/50
# 1998/1998 [==============================] - 0s 207us/sample - loss: 1.1564e-04
# Epoch 50/50
# 1998/1998 [==============================] - 0s 197us/sample - loss: 1.2439e-04

# %%
x_test_len=m.ceil(X.shape[0]*0.2)
X_Test=X[x_test_len:]
x_test=list()
y_test=list()
X_Test=X[x_test_len:]
x_test=list()
y_test=list()
for i in range(1,x_test_len):
  x_test.append(X_Test[i-1:i])
  y_test.append(X_Test[i,])
x_test=np.array(x_test)
y_test=np.array(y_test)
x_test=np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))
x_test.shape
# Out:
# (499, 1, 1)

# %%
(1-model.evaluate(x_test,y_test))*100
# Out:
# 499/499 [==============================] - 0s 405us/sample - loss: 7.5351e-05
# 99.99246494390137

# %%
today=dt.strftime(dt.today(),'%Y-%m-%d')
df_sbi=web.DataReader('ICICIBANK.NS','yahoo',start='2019-1-1',end=today)
df_sbi=df_sbi.filter(['Close']).values
df_sbi=scaler.fit_transform(df_sbi)
df_sbi_30=df_sbi[-60:,:]
df_sbi_30.shape
# Out:
# (60, 1)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
model.save('/content/gdrive/My Drive/Colab Notebooks/tesla_model.h5')

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler as mms
from tensorflow.keras.models import load_model
model = load_model('/content/gdrive/My Drive/Colab Notebooks/sbi_model_jo_checkkkk.h5')
def sbi_result():
  today=dt.strftime(dt.today(),'%Y-%m-%d')
  df_sbi=web.DataReader('ICICIBANK.NS','yahoo',start='2019-1-1',end=today)
  df_sbi=df_sbi.filter(['Close']).values
  scaler=mms(feature_range=(0,1))
  df_sbi=scaler.fit_transform(df_sbi)
  df_sbi_30=df_sbi[-1:,:]
  y_30=list()
  for i in range(30):
    x_30=list()
    df_sbi_30=np.reshape(df_sbi_30,(df_sbi_30.shape[0],1))
  
    x_30=df_sbi_30[-1:,:]
    x_30=np.array(x_30)
    x_30=np.reshape(x_30,(x_30.shape[1],1,1))
    x=model.predict(x_30)
    y_30.append(x)
    df_sbi_30=np.append(df_sbi_30,x)
  y_30=np.array(y_30)
  y_30=np.reshape(y_30,(y_30.shape[0],y_30.shape[1]))
  y_30=scaler.inverse_transform(y_30)
  result=np.reshape(y_30,(30))
  return result
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling Orthogonal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
list(sbi_result())
# Out:
# [541.9534,
#  537.2898,
#  532.9659,
#  528.945,
#  525.19574,
#  521.69104,
#  518.4075,
#  515.3246,
#  512.4245,
#  509.69138,
#  507.11118,
#  504.6717,
#  502.3618,
#  500.17163,
#  498.0923,
#  496.1158,
#  494.23502,
#  492.44327,
#  490.73474,
#  489.10394,
#  487.54593,
#  486.05627,
#  484.63074,
#  483.2656,
#  481.95724,
#  480.70245,
#  479.49838,
#  478.34204,
#  477.23102,
#  476.16287]
